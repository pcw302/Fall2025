# %%
# !pip install plotly
# !pip install -U kaleido

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
# Data is from: https://github.com/the-pudding/data/tree/master/dog-shelters
dogs = pd.read_csv(r'C:\Users\Parker White\vscode Python\Python\Fall 2025\Data VIs\Data\Dogs Data.txt', sep = '\t')
dogs.head()
# Out:
#          id                   breed_primary     age   sex    size  \
# 0  46042150  American Staffordshire Terrier  Senior  Male  Medium
# 1  46042002                Pit Bull Terrier   Adult  Male   Large
# 2  46040898                        Shepherd   Adult  Male   Large
# 3  46039306                       Dachshund   Young  Male   Small
# 4  46039304                           Boxer    Baby  Male  Medium
#
#   contact_state                                        description
# 0            NV  Harley is not sure how he wound up at shelter ...
# 1            NV  6 year old Biggie has lost his home and really...
# 2            NV  Approx 2 years old. Did I catch your eye? I do...
# 3            NV  Theo is a friendly dachshund mix who gets alon...
# 4            NV  Oliver was born around mid-June and came to us...

# %%
dogs['age'].value_counts()
# Out:
# age
# Adult     10918
# Young      6727
# Baby       4312
# Senior     2123
# Name: count, dtype: int64

# %%
dogs.shape
# Out:
# (24080, 7)

# %% [markdown]
# An edited donut chart like the one in the slides is shown below. Make the changes requested and answer the questions:<br>
#
# 1) Since we have the names inside the pie slices, we don't really need the legend. Add the argument `showlegend=False` into update_layout to remove it. <br>
# 2) Which part of the code writes the text in the center of the donut? How is this text specified (in terms of any formatting information)? <br>
# 3) What does the format code (this is asking about the comma, like {value:,}) do (you should see it in two places)? <br>
# 4) How did we get lines around the donut segments? <br>
# 5) What would I change to remove the labels from the hovertext, i.e., I just want it to say the number, not to repeat the name of the category? <br>
# 6) What happens if we delete the hoverlabel dictionary (delete from hoverlabel to the comma)? Why do you think we made this change in the first place?

# %%
labels = dogs['age'].value_counts().index #So you get the columns
colors = ['cornflowerblue', 'skyblue', 'lightblue', 'navy'] # Why these colors? # Reordered to match data
# Better way to do this is to make variable categorical and ordinal in data frame
values = dogs['age'].value_counts().values
# Out:
# array([10918,  6727,  4312,  2123])

# %%
fig = go.Figure(go.Pie(
    values= values,
    labels= labels,
    hole=0.5,
    
    
    
    
    
))

fig.update_layout(
        annotations=[
            {
                'text': f'<span style' = 
            }
        ]
)
# fig.write_html('Images/Dog_Donut.html')                          
fig.show()
